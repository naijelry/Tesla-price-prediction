# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Load the dataset (ensure that it's not too large for memory)
file_path = '/content/tesla_stock_data_final_cleaneddata(noduplciates_nomissingvalues).csv'  # Adjust path if needed
df = pd.read_csv(file_path)

# Optimize the data types of columns to reduce memory usage
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['year'] = df['timestamp'].dt.year.astype('int16')
df['month'] = df['timestamp'].dt.month.astype('int8')
df['day_of_week'] = df['timestamp'].dt.dayofweek.astype('int8')
df['week_of_year'] = df['timestamp'].dt.isocalendar().week.astype('int8')

# Use 'float32' or 'int32' where applicable to save memory
df['close'] = df['close'].astype('float32')
df['high'] = df['high'].astype('float32')
df['low'] = df['low'].astype('float32')
df['open'] = df['open'].astype('float32')

# Feature Engineering: Keep it simple with lag features and rolling stats
# 1. Lag Features (7, 14, and 30 days)
df['high_lag_7'] = df['high'].shift(7)
df['low_lag_7'] = df['low'].shift(7)
df['close_lag_7'] = df['close'].shift(7)

df['high_lag_14'] = df['high'].shift(14)
df['low_lag_14'] = df['low'].shift(14)
df['close_lag_14'] = df['close'].shift(14)

df['high_lag_30'] = df['high'].shift(30)
df['low_lag_30'] = df['low'].shift(30)
df['close_lag_30'] = df['close'].shift(30)

# 2. Rolling Features (30-day rolling mean and std)
df['close_rolling_mean_30'] = df['close'].rolling(window=30).mean().astype('float32')
df['high_rolling_mean_30'] = df['high'].rolling(window=30).mean().astype('float32')
df['low_rolling_mean_30'] = df['low'].rolling(window=30).mean().astype('float32')

df['close_rolling_std_30'] = df['close'].rolling(window=30).std().astype('float32')
df['high_rolling_std_30'] = df['high'].rolling(window=30).std().astype('float32')
df['low_rolling_std_30'] = df['low'].rolling(window=30).std().astype('float32')

# 3. Price Differences
df['price_diff'] = (df['high'] - df['low']).astype('float32')
df['close_open_diff'] = (df['close'] - df['open']).astype('float32')

# 4. Moving Averages (50 and 200 days)
df['close_50ma'] = df['close'].rolling(window=50).mean().astype('float32')
df['close_200ma'] = df['close'].rolling(window=200).mean().astype('float32')

# Drop rows with NaN values (created by rolling and lagging)
df = df.dropna()

# Prepare Features and Target Variables
X = df[['year', 'month', 'day_of_week', 'week_of_year',
        'close_rolling_mean_30', 'high_rolling_mean_30', 'low_rolling_mean_30',
        'close_rolling_std_30', 'high_rolling_std_30', 'low_rolling_std_30',
        'price_diff', 'close_open_diff', 'close_50ma', 'close_200ma',
        'high_lag_7', 'low_lag_7', 'close_lag_7',
        'high_lag_14', 'low_lag_14', 'close_lag_14',
        'high_lag_30', 'low_lag_30', 'close_lag_30']]

# Target Variables (high and low prices)
y_high = df['high']
y_low = df['low']

# %%
import time
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# Split the Data into Training and Testing Sets (80-20 split)
X_train, X_test, y_train_high, y_test_high, y_train_low, y_test_low = train_test_split(
    X, y_high, y_low, test_size=0.2, shuffle=False
)

# Define the desired batch size (adjustable)
batch_size = 50000  # You can change this value to control the batch size

# Calculate number of batches
num_batches = len(X_train) // batch_size + (1 if len(X_train) % batch_size != 0 else 0)

# Create batches manually
X_train_batches = [X_train[i * batch_size : (i + 1) * batch_size] for i in range(num_batches)]
y_train_high_batches = [y_train_high[i * batch_size : (i + 1) * batch_size] for i in range(num_batches)]
y_train_low_batches = [y_train_low[i * batch_size : (i + 1) * batch_size] for i in range(num_batches)]

# Initialize the models
model_high = RandomForestRegressor(n_estimators=50, random_state=42)
model_low = RandomForestRegressor(n_estimators=50, random_state=42)

# Initialize variables to track total training time
total_training_time_high = 0
total_training_time_low = 0

# Measure training time for High and Low Price models in batches
for batch_num in range(num_batches):
    # Get the current batch of data
    X_batch = X_train_batches[batch_num]
    y_batch_high = y_train_high_batches[batch_num]
    y_batch_low = y_train_low_batches[batch_num]

    # Calculate the range of samples for the current batch
    start_index = batch_num * len(X_batch)
    end_index = start_index + len(X_batch) - 1

    # Display the sample range being trained on
    print(f"Training on batch from sample {start_index} to {end_index} (Batch size: {len(X_batch)} samples)")

    # Measure training time for High Price Prediction model
    start_time_high = time.time()
    model_high.fit(X_batch, y_batch_high)
    end_time_high = time.time()
    training_time_high = end_time_high - start_time_high
    total_training_time_high += training_time_high
    print(f"Training time for high price model (Batch): {training_time_high:.2f} seconds")

    # Measure training time for Low Price Prediction model
    start_time_low = time.time()
    model_low.fit(X_batch, y_batch_low)
    end_time_low = time.time()
    training_time_low = end_time_low - start_time_low
    total_training_time_low += training_time_low
    print(f"Training time for low price model (Batch): {training_time_low:.2f} seconds")

# Output the total training time after all batches are processed
print(f"Total training time for High Price model: {total_training_time_high:.2f} seconds")
print(f"Total training time for Low Price model: {total_training_time_low:.2f} seconds")

# Evaluate the models on the Test Set after all batches are trained
y_pred_high = model_high.predict(X_test)
y_pred_low = model_low.predict(X_test)

# Calculate Mean Absolute Error (MAE), Mean Squared Error (MSE), and R-squared (R²) for both predictions
mae_high = mean_absolute_error(y_test_high, y_pred_high)
mae_low = mean_absolute_error(y_test_low, y_pred_low)

mse_high = mean_squared_error(y_test_high, y_pred_high)
mse_low = mean_squared_error(y_test_low, y_pred_low)

r2_high = r2_score(y_test_high, y_pred_high)
r2_low = r2_score(y_test_low, y_pred_low)

# Print the evaluation metrics after all batches have been trained
print(f'Mean Absolute Error for High Price Prediction: {mae_high:.4f}')
print(f'Mean Absolute Error for Low Price Prediction: {mae_low:.4f}')
print(f'Mean Squared Error for High Price Prediction: {mse_high:.4f}')
print(f'Mean Squared Error for Low Price Prediction: {mse_low:.4f}')
print(f'R-squared for High Price Prediction: {r2_high:.4f}')
print(f'R-squared for Low Price Prediction: {r2_low:.4f}')
# Out:
# Training on batch from sample 0 to 49999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 78.37 seconds
# Training time for low price model (Batch): 77.76 seconds
# Training on batch from sample 50000 to 99999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 80.12 seconds
# Training time for low price model (Batch): 79.86 seconds
# Training on batch from sample 100000 to 149999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 75.74 seconds
# Training time for low price model (Batch): 76.13 seconds
# Training on batch from sample 150000 to 199999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 75.04 seconds
# Training time for low price model (Batch): 74.17 seconds
# Training on batch from sample 200000 to 249999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 71.67 seconds
# Training time for low price model (Batch): 72.44 seconds
# Training on batch from sample 250000 to 299999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 76.12 seconds
# Training time for low price model (Batch): 75.03 seconds
# Training on batch from sample 300000 to 349999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 74.76 seconds
# Training time for low price model (Batch): 74.01 seconds
# Training on batch from sample 350000 to 399999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 74.87 seconds
# Training time for low price model (Batch): 76.02 seconds
# Training on batch from sample 400000 to 449999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 77.81 seconds
# Training time for low price model (Batch): 78.60 seconds
# Training on batch from sample 450000 to 499999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 76.77 seconds
# Training time for low price model (Batch): 77.43 seconds
# Training on batch from sample 500000 to 549999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 81.14 seconds
# Training time for low price model (Batch): 81.38 seconds
# Training on batch from sample 550000 to 599999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 79.56 seconds
# Training time for low price model (Batch): 79.39 seconds
# Training on batch from sample 600000 to 649999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 82.05 seconds
# Training time for low price model (Batch): 81.03 seconds
# Training on batch from sample 650000 to 699999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 75.78 seconds
# Training time for low price model (Batch): 74.68 seconds
# Training on batch from sample 700000 to 749999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 75.13 seconds
# Training time for low price model (Batch): 74.27 seconds
# Training on batch from sample 750000 to 799999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 76.35 seconds
# Training time for low price model (Batch): 77.13 seconds
# Training on batch from sample 800000 to 849999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 76.97 seconds
# Training time for low price model (Batch): 78.81 seconds
# Training on batch from sample 850000 to 899999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 79.70 seconds
# Training time for low price model (Batch): 78.92 seconds
# Training on batch from sample 900000 to 949999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 75.14 seconds
# Training time for low price model (Batch): 73.45 seconds
# Training on batch from sample 950000 to 999999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 77.67 seconds
# Training time for low price model (Batch): 77.37 seconds
# Training on batch from sample 1000000 to 1049999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 76.30 seconds
# Training time for low price model (Batch): 76.82 seconds
# Training on batch from sample 1050000 to 1099999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 79.48 seconds
# Training time for low price model (Batch): 78.38 seconds
# Training on batch from sample 1100000 to 1149999 (Batch size: 50000 samples)
# Training time for high price model (Batch): 79.42 seconds
# Training time for low price model (Batch): 79.55 seconds
# Training on batch from sample 998338 to 1041743 (Batch size: 43406 samples)
# Training time for high price model (Batch): 67.73 seconds
# Training time for low price model (Batch): 67.62 seconds
# Total training time for High Price model: 1843.70 seconds
# Total training time for Low Price model: 1840.23 seconds
# Mean Absolute Error for High Price Prediction: 96.9177
# Mean Absolute Error for Low Price Prediction: 91.2931
# Mean Squared Error for High Price Prediction: 13156.7035
# Mean Squared Error for Low Price Prediction: 11988.6946
# R-squared for High Price Prediction: 0.2486
# R-squared for Low Price Prediction: 0.3134

# %%
import time
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from scipy.stats import randint

# Split the Data into Training and Testing Sets (80-20 split)
X_train, X_test, y_train_high, y_test_high, y_train_low, y_test_low = train_test_split(
    X, y_high, y_low, test_size=0.2, shuffle=False
)

# Define the Random Forest Hyperparameter Grid (Optimized)
param_dist = {
    'n_estimators': randint(100, 120),  # Smaller range for number of trees
    'max_depth': randint(5, 10),         # Limit maximum depth
    'min_samples_split': randint(2, 6),  # Reduced range
    'min_samples_leaf': randint(1, 6),   # Reduced range
    'max_features': ['sqrt', 'log2'],    # Keep as is
    'bootstrap': [True, False]            # Keep as is
}

# Initialize the models
model_high = RandomForestRegressor(random_state=42, n_jobs=-1)
model_low = RandomForestRegressor(random_state=42, n_jobs=-1)

# Initialize RandomizedSearchCV for hyperparameter tuning with fewer iterations and cross-validation folds
random_search_high = RandomizedSearchCV(model_high, param_dist, n_iter=3, cv=2, random_state=42, n_jobs=-1, verbose=2)
random_search_low = RandomizedSearchCV(model_low, param_dist, n_iter=3, cv=2, random_state=42, n_jobs=-1, verbose=2)

# Define the desired batch size
batch_size = 10000  # Reduced batch size

# Calculate the number of batches
num_batches = len(X_train) // batch_size + (1 if len(X_train) % batch_size != 0 else 0)

# Create batches manually
X_train_batches = [X_train[i * batch_size : (i + 1) * batch_size] for i in range(num_batches)]
y_train_high_batches = [y_train_high[i * batch_size : (i + 1) * batch_size] for i in range(num_batches)]
y_train_low_batches = [y_train_low[i * batch_size : (i + 1) * batch_size] for i in range(num_batches)]

# Initialize variables to track total training time
total_training_time_high = 0
total_training_time_low = 0

# Track predictions for evaluation
y_pred_high = []
y_pred_low = []

# Measure and train the models on batches
for batch_num in range(num_batches):
    # Get the current batch of data
    X_batch = X_train_batches[batch_num]
    y_batch_high = y_train_high_batches[batch_num]
    y_batch_low = y_train_low_batches[batch_num]

    # Calculate the range of samples for the current batch
    start_index = batch_num * len(X_batch)
    end_index = start_index + len(X_batch) - 1

    # Display the sample range being trained on
    print(f"Training on batch from sample {start_index} to {end_index} (Batch size: {len(X_batch)} samples)")

    # Fit the RandomizedSearchCV on the batch for High Price Prediction
    start_time_high = time.time()
    random_search_high.fit(X_batch, y_batch_high)
    end_time_high = time.time()
    training_time_high = end_time_high - start_time_high
    total_training_time_high += training_time_high
    print(f"Training time for high price model (Batch): {training_time_high:.2f} seconds")

    # Fit the RandomizedSearchCV on the batch for Low Price Prediction
    start_time_low = time.time()
    random_search_low.fit(X_batch, y_batch_low)
    end_time_low = time.time()
    training_time_low = end_time_low - start_time_low
    total_training_time_low += training_time_low
    print(f"Training time for low price model (Batch): {training_time_low:.2f} seconds")

# Output the total training time
print(f"Total training time for High Price model: {total_training_time_high:.2f} seconds")
print(f"Total training time for Low Price model: {total_training_time_low:.2f} seconds")

# Output the best hyperparameters for both models
print("Best hyperparameters for High Price Model:")
print(random_search_high.best_params_)

print("Best hyperparameters for Low Price Model:")
print(random_search_low.best_params_)

# Use the best models found by RandomizedSearchCV
best_model_high = random_search_high.best_estimator_
best_model_low = random_search_low.best_estimator_

# Make predictions for the entire test set after training is complete
y_pred_high = best_model_high.predict(X_test)
y_pred_low = best_model_low.predict(X_test)

# Calculate Mean Absolute Error (MAE), Mean Squared Error (MSE), and R-squared (R²) for both predictions
mae_high = mean_absolute_error(y_test_high, y_pred_high)
mae_low = mean_absolute_error(y_test_low, y_pred_low)

mse_high = mean_squared_error(y_test_high, y_pred_high)
mse_low = mean_squared_error(y_test_low, y_pred_low)

r2_high = r2_score(y_test_high, y_pred_high)
r2_low = r2_score(y_test_low, y_pred_low)
# Out:
# Training on batch from sample 0 to 9999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 19.22 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 15.08 seconds
# Training on batch from sample 10000 to 19999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.39 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.05 seconds
# Training on batch from sample 20000 to 29999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.72 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.53 seconds
# Training on batch from sample 30000 to 39999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.40 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.63 seconds
# Training on batch from sample 40000 to 49999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.12 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.17 seconds
# Training on batch from sample 50000 to 59999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.30 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.49 seconds
# Training on batch from sample 60000 to 69999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.41 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.41 seconds
# Training on batch from sample 70000 to 79999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.91 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.56 seconds
# Training on batch from sample 80000 to 89999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.68 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.30 seconds
# Training on batch from sample 90000 to 99999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.22 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.52 seconds
# Training on batch from sample 100000 to 109999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.27 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.60 seconds
# Training on batch from sample 110000 to 119999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.87 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.55 seconds
# Training on batch from sample 120000 to 129999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.62 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.12 seconds
# Training on batch from sample 130000 to 139999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.37 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.18 seconds
# Training on batch from sample 140000 to 149999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.60 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.96 seconds
# Training on batch from sample 150000 to 159999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.01 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.95 seconds
# Training on batch from sample 160000 to 169999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.85 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.70 seconds
# Training on batch from sample 170000 to 179999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.53 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.24 seconds
# Training on batch from sample 180000 to 189999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.14 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.55 seconds
# Training on batch from sample 190000 to 199999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.96 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.78 seconds
# Training on batch from sample 200000 to 209999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.73 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.86 seconds
# Training on batch from sample 210000 to 219999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.83 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 7.98 seconds
# Training on batch from sample 220000 to 229999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.57 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.40 seconds
# Training on batch from sample 230000 to 239999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.89 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.35 seconds
# Training on batch from sample 240000 to 249999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.32 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.14 seconds
# Training on batch from sample 250000 to 259999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.84 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.22 seconds
# Training on batch from sample 260000 to 269999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.86 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.78 seconds
# Training on batch from sample 270000 to 279999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.03 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.29 seconds
# Training on batch from sample 280000 to 289999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.77 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.28 seconds
# Training on batch from sample 290000 to 299999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.06 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.21 seconds
# Training on batch from sample 300000 to 309999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.67 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.47 seconds
# Training on batch from sample 310000 to 319999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.86 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.42 seconds
# Training on batch from sample 320000 to 329999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.43 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.61 seconds
# Training on batch from sample 330000 to 339999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.51 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.43 seconds
# Training on batch from sample 340000 to 349999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.10 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.13 seconds
# Training on batch from sample 350000 to 359999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.22 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.79 seconds
# Training on batch from sample 360000 to 369999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.59 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.55 seconds
# Training on batch from sample 370000 to 379999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.23 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.65 seconds
# Training on batch from sample 380000 to 389999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.35 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 12.43 seconds
# Training on batch from sample 390000 to 399999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.32 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.20 seconds
# Training on batch from sample 400000 to 409999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.27 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.70 seconds
# Training on batch from sample 410000 to 419999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.19 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.06 seconds
# Training on batch from sample 420000 to 429999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.35 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.39 seconds
# Training on batch from sample 430000 to 439999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.47 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.76 seconds
# Training on batch from sample 440000 to 449999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.73 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.55 seconds
# Training on batch from sample 450000 to 459999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.59 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.35 seconds
# Training on batch from sample 460000 to 469999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.84 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.90 seconds
# Training on batch from sample 470000 to 479999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.80 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.12 seconds
# Training on batch from sample 480000 to 489999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.54 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.26 seconds
# Training on batch from sample 490000 to 499999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.80 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.75 seconds
# Training on batch from sample 500000 to 509999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 12.09 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.25 seconds
# Training on batch from sample 510000 to 519999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.34 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.73 seconds
# Training on batch from sample 520000 to 529999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.45 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.05 seconds
# Training on batch from sample 530000 to 539999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.45 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.51 seconds
# Training on batch from sample 540000 to 549999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.68 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.67 seconds
# Training on batch from sample 550000 to 559999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.15 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.37 seconds
# Training on batch from sample 560000 to 569999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.31 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.96 seconds
# Training on batch from sample 570000 to 579999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.46 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.58 seconds
# Training on batch from sample 580000 to 589999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.01 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.19 seconds
# Training on batch from sample 590000 to 599999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.42 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.96 seconds
# Training on batch from sample 600000 to 609999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.87 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.44 seconds
# Training on batch from sample 610000 to 619999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.94 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.73 seconds
# Training on batch from sample 620000 to 629999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.72 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.21 seconds
# Training on batch from sample 630000 to 639999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.89 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.47 seconds
# Training on batch from sample 640000 to 649999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.54 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.15 seconds
# Training on batch from sample 650000 to 659999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.33 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.87 seconds
# Training on batch from sample 660000 to 669999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.64 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.67 seconds
# Training on batch from sample 670000 to 679999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.17 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.44 seconds
# Training on batch from sample 680000 to 689999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.93 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.38 seconds
# Training on batch from sample 690000 to 699999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.03 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.01 seconds
# Training on batch from sample 700000 to 709999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.72 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.16 seconds
# Training on batch from sample 710000 to 719999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.99 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.98 seconds
# Training on batch from sample 720000 to 729999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.49 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.69 seconds
# Training on batch from sample 730000 to 739999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.37 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.90 seconds
# Training on batch from sample 740000 to 749999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.25 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.19 seconds
# Training on batch from sample 750000 to 759999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.61 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.54 seconds
# Training on batch from sample 760000 to 769999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.95 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.36 seconds
# Training on batch from sample 770000 to 779999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.75 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.89 seconds
# Training on batch from sample 780000 to 789999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.70 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.53 seconds
# Training on batch from sample 790000 to 799999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.26 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.74 seconds
# Training on batch from sample 800000 to 809999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.50 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.40 seconds
# Training on batch from sample 810000 to 819999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.32 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.65 seconds
# Training on batch from sample 820000 to 829999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 12.04 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.88 seconds
# Training on batch from sample 830000 to 839999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.61 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.96 seconds
# Training on batch from sample 840000 to 849999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.56 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.08 seconds
# Training on batch from sample 850000 to 859999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.36 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.14 seconds
# Training on batch from sample 860000 to 869999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.44 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.28 seconds
# Training on batch from sample 870000 to 879999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.74 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.64 seconds
# Training on batch from sample 880000 to 889999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.08 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.46 seconds
# Training on batch from sample 890000 to 899999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.03 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.95 seconds
# Training on batch from sample 900000 to 909999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.61 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.16 seconds
# Training on batch from sample 910000 to 919999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.67 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.56 seconds
# Training on batch from sample 920000 to 929999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.74 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.42 seconds
# Training on batch from sample 930000 to 939999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.57 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.08 seconds
# Training on batch from sample 940000 to 949999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.41 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.68 seconds
# Training on batch from sample 950000 to 959999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.53 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.86 seconds
# Training on batch from sample 960000 to 969999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.63 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.66 seconds
# Training on batch from sample 970000 to 979999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.96 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.15 seconds
# Training on batch from sample 980000 to 989999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.08 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.45 seconds
# Training on batch from sample 990000 to 999999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.29 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.71 seconds
# Training on batch from sample 1000000 to 1009999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.82 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.78 seconds
# Training on batch from sample 1010000 to 1019999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.77 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.75 seconds
# Training on batch from sample 1020000 to 1029999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.87 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.82 seconds
# Training on batch from sample 1030000 to 1039999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.67 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.53 seconds
# Training on batch from sample 1040000 to 1049999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 12.03 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.41 seconds
# Training on batch from sample 1050000 to 1059999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.34 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.81 seconds
# Training on batch from sample 1060000 to 1069999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.58 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.07 seconds
# Training on batch from sample 1070000 to 1079999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.95 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.36 seconds
# Training on batch from sample 1080000 to 1089999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.24 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.59 seconds
# Training on batch from sample 1090000 to 1099999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.25 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.14 seconds
# Training on batch from sample 1100000 to 1109999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 12.01 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 12.17 seconds
# Training on batch from sample 1110000 to 1119999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 8.83 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.68 seconds
# Training on batch from sample 1120000 to 1129999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.71 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 9.03 seconds
# Training on batch from sample 1130000 to 1139999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 12.33 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.53 seconds
# Training on batch from sample 1140000 to 1149999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 9.12 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 11.53 seconds
# Training on batch from sample 1150000 to 1159999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.18 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.91 seconds
# Training on batch from sample 1160000 to 1169999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.17 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 12.15 seconds
# Training on batch from sample 1170000 to 1179999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 10.21 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 10.53 seconds
# Training on batch from sample 1180000 to 1189999 (Batch size: 10000 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 11.39 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 8.91 seconds
# Training on batch from sample 405314 to 408719 (Batch size: 3406 samples)
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for high price model (Batch): 6.07 seconds
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# Training time for low price model (Batch): 3.45 seconds
# Total training time for High Price model: 1263.53 seconds
# Total training time for Low Price model: 1236.34 seconds
# Best hyperparameters for High Price Model:
# {'bootstrap': False, 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 103}
# Best hyperparameters for Low Price Model:
# {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 106}

# %%
# Print all the metrics in one statement
print(f'Mean Absolute Error for High Price Prediction: {mae_high:.4f}')
print(f'Mean Absolute Error for Low Price Prediction: {mae_low:.4f}')
print(f'Mean Squared Error for High Price Prediction: {mse_high:.4f}')
print(f'Mean Squared Error for Low Price Prediction: {mse_low:.4f}')
print(f'R-squared for High Price Prediction: {r2_high:.4f}')
print(f'R-squared for Low Price Prediction: {r2_low:.4f}')
# Out:
# Mean Absolute Error for High Price Prediction: 5.4532
# Mean Absolute Error for Low Price Prediction: 4.1234
# Mean Squared Error for High Price Prediction: 29.6782
# Mean Squared Error for Low Price Prediction: 17.2231
# R-squared for High Price Prediction: 0.8214
# R-squared for Low Price Prediction: 0.8743
